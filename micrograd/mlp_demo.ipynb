# %%
from nn import MLP
import random as r

# %%
# creating a tiny dataset
size = 8192
x = [[r.uniform(-1,1) for _ in range(4)] for _ in range(size)]
y = []
for features in x:
    # Create a pattern: y = 2*x1 - 0.5*x2 + 3*x3 - x4 + noise
    y_value = (
        2 * features[0]
        - 0.5 * features[1]
        + 3 * features[2]
        - features[3]
        + r.uniform(-0.1, 0.1)  # Add some noise
    )
    y.append(y_value)

# %%
# initialize an MLP with 4 input neurons, hidden_dim of 32, and 1 output neuron
model = MLP(len(x[0]), len(x[0])*8, 1)
model.parameters()
# Out:
# [Value(data=0.591, grad=0.000),
#  Value(data=0.686, grad=0.000),
#  Value(data=0.750, grad=0.000),
#  Value(data=0.171, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.970, grad=0.000),
#  Value(data=0.814, grad=0.000),
#  Value(data=0.006, grad=0.000),
#  Value(data=0.429, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.732, grad=0.000),
#  Value(data=-0.847, grad=0.000),
#  Value(data=-0.311, grad=0.000),
#  Value(data=0.203, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.978, grad=0.000),
#  Value(data=0.366, grad=0.000),
#  Value(data=-0.787, grad=0.000),
#  Value(data=-0.731, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.823, grad=0.000),
#  Value(data=0.980, grad=0.000),
#  Value(data=-0.180, grad=0.000),
#  Value(data=0.590, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.297, grad=0.000),
#  Value(data=0.679, grad=0.000),
#  Value(data=0.606, grad=0.000),
#  Value(data=-0.383, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.924, grad=0.000),
#  Value(data=-0.357, grad=0.000),
#  Value(data=0.361, grad=0.000),
#  Value(data=0.657, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.718, grad=0.000),
#  Value(data=-0.976, grad=0.000),
#  Value(data=-0.062, grad=0.000),
#  Value(data=-0.322, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.075, grad=0.000),
#  Value(data=-0.072, grad=0.000),
#  Value(data=0.425, grad=0.000),
#  Value(data=0.679, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.882, grad=0.000),
#  Value(data=0.566, grad=0.000),
#  Value(data=-0.124, grad=0.000),
#  Value(data=0.560, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.507, grad=0.000),
#  Value(data=-0.810, grad=0.000),
#  Value(data=-0.531, grad=0.000),
#  Value(data=0.044, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.383, grad=0.000),
#  Value(data=0.268, grad=0.000),
#  Value(data=0.857, grad=0.000),
#  Value(data=0.100, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.901, grad=0.000),
#  Value(data=0.453, grad=0.000),
#  Value(data=0.665, grad=0.000),
#  Value(data=0.850, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.335, grad=0.000),
#  Value(data=-0.361, grad=0.000),
#  Value(data=-0.276, grad=0.000),
#  Value(data=-0.133, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.287, grad=0.000),
#  Value(data=0.504, grad=0.000),
#  Value(data=-0.265, grad=0.000),
#  Value(data=-0.351, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.150, grad=0.000),
#  Value(data=-0.416, grad=0.000),
#  Value(data=-0.561, grad=0.000),
#  Value(data=0.856, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.694, grad=0.000),
#  Value(data=0.771, grad=0.000),
#  Value(data=0.366, grad=0.000),
#  Value(data=0.770, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.419, grad=0.000),
#  Value(data=0.437, grad=0.000),
#  Value(data=-0.691, grad=0.000),
#  Value(data=-0.624, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.525, grad=0.000),
#  Value(data=-0.843, grad=0.000),
#  Value(data=0.087, grad=0.000),
#  Value(data=0.369, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.044, grad=0.000),
#  Value(data=0.246, grad=0.000),
#  Value(data=0.559, grad=0.000),
#  Value(data=0.073, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.862, grad=0.000),
#  Value(data=-0.550, grad=0.000),
#  Value(data=0.386, grad=0.000),
#  Value(data=0.164, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.207, grad=0.000),
#  Value(data=-0.580, grad=0.000),
#  Value(data=-0.638, grad=0.000),
#  Value(data=-0.490, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.410, grad=0.000),
#  Value(data=-0.489, grad=0.000),
#  Value(data=0.622, grad=0.000),
#  Value(data=0.710, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.958, grad=0.000),
#  Value(data=-0.944, grad=0.000),
#  Value(data=-0.203, grad=0.000),
#  Value(data=-0.386, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.676, grad=0.000),
#  Value(data=0.374, grad=0.000),
#  Value(data=0.370, grad=0.000),
#  Value(data=-0.742, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.612, grad=0.000),
#  Value(data=0.650, grad=0.000),
#  Value(data=-0.079, grad=0.000),
#  Value(data=-0.698, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.292, grad=0.000),
#  Value(data=0.136, grad=0.000),
#  Value(data=0.502, grad=0.000),
#  Value(data=-0.386, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.702, grad=0.000),
#  Value(data=-0.535, grad=0.000),
#  Value(data=0.131, grad=0.000),
#  Value(data=0.134, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.168, grad=0.000),
#  Value(data=-0.506, grad=0.000),
#  Value(data=0.111, grad=0.000),
#  Value(data=0.299, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.585, grad=0.000),
#  Value(data=0.548, grad=0.000),
#  Value(data=-0.067, grad=0.000),
#  Value(data=0.943, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.051, grad=0.000),
#  Value(data=0.745, grad=0.000),
#  Value(data=0.062, grad=0.000),
#  Value(data=-0.959, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.393, grad=0.000),
#  Value(data=0.462, grad=0.000),
#  Value(data=-0.486, grad=0.000),
#  Value(data=0.988, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=0.057, grad=0.000),
#  Value(data=-0.461, grad=0.000),
#  Value(data=-0.703, grad=0.000),
#  Value(data=-0.270, grad=0.000),
#  Value(data=-0.222, grad=0.000),
#  Value(data=0.246, grad=0.000),
#  Value(data=0.643, grad=0.000),
#  Value(data=-0.797, grad=0.000),
#  Value(data=-0.747, grad=0.000),
#  Value(data=-0.176, grad=0.000),
#  Value(data=-0.997, grad=0.000),
#  Value(data=-0.980, grad=0.000),
#  Value(data=-0.767, grad=0.000),
#  Value(data=-0.937, grad=0.000),
#  Value(data=-0.502, grad=0.000),
#  Value(data=-0.881, grad=0.000),
#  Value(data=-0.943, grad=0.000),
#  Value(data=0.431, grad=0.000),
#  Value(data=-0.982, grad=0.000),
#  Value(data=-0.669, grad=0.000),
#  Value(data=0.514, grad=0.000),
#  Value(data=-0.398, grad=0.000),
#  Value(data=0.552, grad=0.000),
#  Value(data=0.191, grad=0.000),
#  Value(data=-0.385, grad=0.000),
#  Value(data=-0.420, grad=0.000),
#  Value(data=-0.593, grad=0.000),
#  Value(data=-0.905, grad=0.000),
#  Value(data=0.313, grad=0.000),
#  Value(data=0.283, grad=0.000),
#  Value(data=-0.592, grad=0.000),
#  Value(data=-0.210, grad=0.000),
#  Value(data=0.000, grad=0.000)]

# %%
# initial loss on test set, which will just be the final batch in the dataset
batch_size = 16
x_test = x[-batch_size:]
y_test = y[-batch_size:]

# running the model over the dataset
ypred = []
for j in range(batch_size):
    ypred.append(model(x_test[j]))

# MSE loss function
loss_batch = [(yhat - ytrue)**2 for ytrue, yhat in zip(y_test, ypred)]
loss = 0.0
for k in loss_batch: # sum() doesn't work for some reason so we've gotta do it manually
    loss = loss + k
    
print(f'initial test set loss: {loss}')
# Out:
# initial test set loss: Value(data=174.123, grad=0.000)

# %%
# training loop
eta = 0.0001
for i in range(1, (size // batch_size) - batch_size): # 1 bc we already did one step. -batch_size for test set
    x_batch = x[i*batch_size:i*batch_size + batch_size]
    y_batch = y[i*batch_size:i*batch_size + batch_size]

    ## forward pass
    # running the model over the dataset
    ypred = []
    for j in range(batch_size):
        ypred.append(model(x_batch[j]))
    
    # MSE loss function
    loss_batch = [(yhat - ytrue)**2 for ytrue, yhat in zip(y_batch, ypred)]
    loss = 0.0
    for k in loss_batch: # sum() doesn't work for some reason so we've gotta do it manually
        loss = loss + k
    print(f'step {i} loss: {loss}')

    ## backward pass
    #set params to 0
    for p in model.parameters():
        p.grad = 0.0
    # clac gradients
    loss.backward()
    # performing a step of SGD
    for p in model.parameters():
        p.data += -eta * p.grad
# Out:
# step 1 loss: Value(data=230.156, grad=0.000)
# step 2 loss: Value(data=278.105, grad=0.000)
# step 3 loss: Value(data=191.795, grad=0.000)
# step 4 loss: Value(data=138.799, grad=0.000)
# step 5 loss: Value(data=77.813, grad=0.000)
# step 6 loss: Value(data=93.909, grad=0.000)
# step 7 loss: Value(data=172.336, grad=0.000)
# step 8 loss: Value(data=182.626, grad=0.000)
# step 9 loss: Value(data=147.849, grad=0.000)
# step 10 loss: Value(data=137.614, grad=0.000)
# step 11 loss: Value(data=88.470, grad=0.000)
# step 12 loss: Value(data=194.983, grad=0.000)
# step 13 loss: Value(data=152.301, grad=0.000)
# step 14 loss: Value(data=161.486, grad=0.000)
# step 15 loss: Value(data=108.765, grad=0.000)
# step 16 loss: Value(data=145.232, grad=0.000)
# step 17 loss: Value(data=100.724, grad=0.000)
# step 18 loss: Value(data=71.252, grad=0.000)
# step 19 loss: Value(data=171.571, grad=0.000)
# step 20 loss: Value(data=155.197, grad=0.000)
# step 21 loss: Value(data=162.979, grad=0.000)
# step 22 loss: Value(data=142.261, grad=0.000)
# step 23 loss: Value(data=115.766, grad=0.000)
# step 24 loss: Value(data=100.184, grad=0.000)
# step 25 loss: Value(data=100.237, grad=0.000)
# step 26 loss: Value(data=81.588, grad=0.000)
# step 27 loss: Value(data=81.240, grad=0.000)
# step 28 loss: Value(data=79.835, grad=0.000)
# step 29 loss: Value(data=51.399, grad=0.000)
# step 30 loss: Value(data=45.406, grad=0.000)
# step 31 loss: Value(data=50.362, grad=0.000)
# step 32 loss: Value(data=65.954, grad=0.000)
# step 33 loss: Value(data=111.601, grad=0.000)
# step 34 loss: Value(data=88.707, grad=0.000)
# step 35 loss: Value(data=125.380, grad=0.000)
# step 36 loss: Value(data=121.595, grad=0.000)
# step 37 loss: Value(data=95.169, grad=0.000)
# step 38 loss: Value(data=63.582, grad=0.000)
# step 39 loss: Value(data=39.362, grad=0.000)
# step 40 loss: Value(data=92.275, grad=0.000)
# step 41 loss: Value(data=84.072, grad=0.000)
# step 42 loss: Value(data=98.490, grad=0.000)
# step 43 loss: Value(data=170.788, grad=0.000)
# step 44 loss: Value(data=42.522, grad=0.000)
# step 45 loss: Value(data=78.953, grad=0.000)
# step 46 loss: Value(data=57.760, grad=0.000)
# step 47 loss: Value(data=108.470, grad=0.000)
# step 48 loss: Value(data=65.005, grad=0.000)
# step 49 loss: Value(data=124.694, grad=0.000)
# step 50 loss: Value(data=49.946, grad=0.000)
# step 51 loss: Value(data=51.816, grad=0.000)
# step 52 loss: Value(data=35.440, grad=0.000)
# step 53 loss: Value(data=46.274, grad=0.000)
# step 54 loss: Value(data=54.037, grad=0.000)
# step 55 loss: Value(data=48.513, grad=0.000)
# step 56 loss: Value(data=44.635, grad=0.000)
# step 57 loss: Value(data=77.439, grad=0.000)
# step 58 loss: Value(data=32.743, grad=0.000)
# step 59 loss: Value(data=43.047, grad=0.000)
# step 60 loss: Value(data=38.584, grad=0.000)
# step 61 loss: Value(data=58.531, grad=0.000)
# step 62 loss: Value(data=43.921, grad=0.000)
# step 63 loss: Value(data=67.948, grad=0.000)
# step 64 loss: Value(data=76.123, grad=0.000)
# step 65 loss: Value(data=63.244, grad=0.000)
# step 66 loss: Value(data=53.338, grad=0.000)
# step 67 loss: Value(data=40.973, grad=0.000)
# step 68 loss: Value(data=39.922, grad=0.000)
# step 69 loss: Value(data=54.614, grad=0.000)
# step 70 loss: Value(data=26.584, grad=0.000)
# step 71 loss: Value(data=94.687, grad=0.000)
# step 72 loss: Value(data=57.853, grad=0.000)
# step 73 loss: Value(data=83.997, grad=0.000)
# step 74 loss: Value(data=47.906, grad=0.000)
# step 75 loss: Value(data=74.637, grad=0.000)
# step 76 loss: Value(data=34.006, grad=0.000)
# step 77 loss: Value(data=41.560, grad=0.000)
# step 78 loss: Value(data=32.686, grad=0.000)
# step 79 loss: Value(data=79.542, grad=0.000)
# step 80 loss: Value(data=22.798, grad=0.000)
# step 81 loss: Value(data=86.860, grad=0.000)
# step 82 loss: Value(data=48.485, grad=0.000)
# step 83 loss: Value(data=47.485, grad=0.000)
# step 84 loss: Value(data=43.762, grad=0.000)
# step 85 loss: Value(data=34.573, grad=0.000)
# step 86 loss: Value(data=38.527, grad=0.000)
# step 87 loss: Value(data=27.534, grad=0.000)
# step 88 loss: Value(data=76.034, grad=0.000)
# step 89 loss: Value(data=35.876, grad=0.000)
# step 90 loss: Value(data=64.249, grad=0.000)
# step 91 loss: Value(data=43.619, grad=0.000)
# step 92 loss: Value(data=44.926, grad=0.000)
# step 93 loss: Value(data=29.918, grad=0.000)
# step 94 loss: Value(data=38.334, grad=0.000)
# step 95 loss: Value(data=16.612, grad=0.000)
# step 96 loss: Value(data=42.253, grad=0.000)
# step 97 loss: Value(data=45.931, grad=0.000)
# step 98 loss: Value(data=43.453, grad=0.000)
# step 99 loss: Value(data=49.398, grad=0.000)
# step 100 loss: Value(data=49.959, grad=0.000)
# step 101 loss: Value(data=22.790, grad=0.000)
# step 102 loss: Value(data=20.099, grad=0.000)
# step 103 loss: Value(data=27.348, grad=0.000)
# step 104 loss: Value(data=24.981, grad=0.000)
# step 105 loss: Value(data=13.681, grad=0.000)
# step 106 loss: Value(data=59.524, grad=0.000)
# step 107 loss: Value(data=27.200, grad=0.000)
# step 108 loss: Value(data=42.138, grad=0.000)
# step 109 loss: Value(data=20.451, grad=0.000)
# step 110 loss: Value(data=39.248, grad=0.000)
# step 111 loss: Value(data=57.561, grad=0.000)
# step 112 loss: Value(data=27.286, grad=0.000)
# step 113 loss: Value(data=15.297, grad=0.000)
# step 114 loss: Value(data=33.298, grad=0.000)
# step 115 loss: Value(data=43.536, grad=0.000)
# step 116 loss: Value(data=36.620, grad=0.000)
# step 117 loss: Value(data=27.571, grad=0.000)
# step 118 loss: Value(data=28.480, grad=0.000)
# step 119 loss: Value(data=37.815, grad=0.000)
# step 120 loss: Value(data=18.285, grad=0.000)
# step 121 loss: Value(data=22.941, grad=0.000)
# step 122 loss: Value(data=41.869, grad=0.000)
# step 123 loss: Value(data=11.258, grad=0.000)
# step 124 loss: Value(data=18.295, grad=0.000)
# step 125 loss: Value(data=59.398, grad=0.000)
# step 126 loss: Value(data=17.562, grad=0.000)
# step 127 loss: Value(data=14.690, grad=0.000)
# step 128 loss: Value(data=23.225, grad=0.000)
# step 129 loss: Value(data=14.215, grad=0.000)
# step 130 loss: Value(data=18.616, grad=0.000)
# step 131 loss: Value(data=38.748, grad=0.000)
# step 132 loss: Value(data=18.124, grad=0.000)
# step 133 loss: Value(data=29.410, grad=0.000)
# step 134 loss: Value(data=19.099, grad=0.000)
# step 135 loss: Value(data=24.826, grad=0.000)
# step 136 loss: Value(data=28.533, grad=0.000)
# step 137 loss: Value(data=30.234, grad=0.000)
# step 138 loss: Value(data=31.190, grad=0.000)
# step 139 loss: Value(data=23.546, grad=0.000)
# step 140 loss: Value(data=16.856, grad=0.000)
# step 141 loss: Value(data=20.724, grad=0.000)
# step 142 loss: Value(data=27.603, grad=0.000)
# step 143 loss: Value(data=25.801, grad=0.000)
# step 144 loss: Value(data=31.437, grad=0.000)
# step 145 loss: Value(data=17.209, grad=0.000)
# step 146 loss: Value(data=16.334, grad=0.000)
# step 147 loss: Value(data=12.984, grad=0.000)
# step 148 loss: Value(data=20.014, grad=0.000)
# step 149 loss: Value(data=21.340, grad=0.000)
# step 150 loss: Value(data=14.590, grad=0.000)
# step 151 loss: Value(data=17.034, grad=0.000)
# step 152 loss: Value(data=16.741, grad=0.000)
# step 153 loss: Value(data=14.898, grad=0.000)
# step 154 loss: Value(data=17.760, grad=0.000)
# step 155 loss: Value(data=15.983, grad=0.000)
# step 156 loss: Value(data=13.594, grad=0.000)
# step 157 loss: Value(data=24.147, grad=0.000)
# step 158 loss: Value(data=28.748, grad=0.000)
# step 159 loss: Value(data=17.172, grad=0.000)
# step 160 loss: Value(data=49.737, grad=0.000)
# step 161 loss: Value(data=27.562, grad=0.000)
# step 162 loss: Value(data=21.391, grad=0.000)
# step 163 loss: Value(data=27.174, grad=0.000)
# step 164 loss: Value(data=22.024, grad=0.000)
# step 165 loss: Value(data=21.297, grad=0.000)
# step 166 loss: Value(data=16.998, grad=0.000)
# step 167 loss: Value(data=18.759, grad=0.000)
# step 168 loss: Value(data=15.457, grad=0.000)
# step 169 loss: Value(data=32.484, grad=0.000)
# step 170 loss: Value(data=20.019, grad=0.000)
# step 171 loss: Value(data=21.764, grad=0.000)
# step 172 loss: Value(data=34.790, grad=0.000)
# step 173 loss: Value(data=17.342, grad=0.000)
# step 174 loss: Value(data=25.986, grad=0.000)
# step 175 loss: Value(data=23.196, grad=0.000)
# step 176 loss: Value(data=17.874, grad=0.000)
# step 177 loss: Value(data=19.262, grad=0.000)
# step 178 loss: Value(data=42.386, grad=0.000)
# step 179 loss: Value(data=19.964, grad=0.000)
# step 180 loss: Value(data=20.886, grad=0.000)
# step 181 loss: Value(data=11.065, grad=0.000)
# step 182 loss: Value(data=16.685, grad=0.000)
# step 183 loss: Value(data=14.996, grad=0.000)
# step 184 loss: Value(data=15.203, grad=0.000)
# step 185 loss: Value(data=24.320, grad=0.000)
# step 186 loss: Value(data=27.663, grad=0.000)
# step 187 loss: Value(data=12.177, grad=0.000)
# step 188 loss: Value(data=34.186, grad=0.000)
# step 189 loss: Value(data=14.688, grad=0.000)
# step 190 loss: Value(data=16.614, grad=0.000)
# step 191 loss: Value(data=10.963, grad=0.000)
# step 192 loss: Value(data=13.464, grad=0.000)
# step 193 loss: Value(data=17.911, grad=0.000)
# step 194 loss: Value(data=18.903, grad=0.000)
# step 195 loss: Value(data=17.479, grad=0.000)
# step 196 loss: Value(data=21.829, grad=0.000)
# step 197 loss: Value(data=16.817, grad=0.000)
# step 198 loss: Value(data=19.797, grad=0.000)
# step 199 loss: Value(data=7.090, grad=0.000)
# step 200 loss: Value(data=16.571, grad=0.000)
# step 201 loss: Value(data=14.030, grad=0.000)
# step 202 loss: Value(data=10.775, grad=0.000)
# step 203 loss: Value(data=22.878, grad=0.000)
# step 204 loss: Value(data=16.473, grad=0.000)
# step 205 loss: Value(data=18.411, grad=0.000)
# step 206 loss: Value(data=10.815, grad=0.000)
# step 207 loss: Value(data=21.631, grad=0.000)
# step 208 loss: Value(data=12.180, grad=0.000)
# step 209 loss: Value(data=14.715, grad=0.000)
# step 210 loss: Value(data=13.214, grad=0.000)
# step 211 loss: Value(data=15.849, grad=0.000)
# step 212 loss: Value(data=12.173, grad=0.000)
# step 213 loss: Value(data=14.575, grad=0.000)
# step 214 loss: Value(data=8.338, grad=0.000)
# step 215 loss: Value(data=7.768, grad=0.000)
# step 216 loss: Value(data=15.540, grad=0.000)
# step 217 loss: Value(data=14.014, grad=0.000)
# step 218 loss: Value(data=15.352, grad=0.000)
# step 219 loss: Value(data=9.999, grad=0.000)
# step 220 loss: Value(data=11.446, grad=0.000)
# step 221 loss: Value(data=12.405, grad=0.000)
# step 222 loss: Value(data=10.258, grad=0.000)
# step 223 loss: Value(data=12.554, grad=0.000)
# step 224 loss: Value(data=13.026, grad=0.000)
# step 225 loss: Value(data=8.708, grad=0.000)
# step 226 loss: Value(data=17.513, grad=0.000)
# step 227 loss: Value(data=6.545, grad=0.000)
# step 228 loss: Value(data=14.676, grad=0.000)
# step 229 loss: Value(data=16.537, grad=0.000)
# step 230 loss: Value(data=10.113, grad=0.000)
# step 231 loss: Value(data=8.146, grad=0.000)
# step 232 loss: Value(data=14.352, grad=0.000)
# step 233 loss: Value(data=13.808, grad=0.000)
# step 234 loss: Value(data=14.566, grad=0.000)
# step 235 loss: Value(data=5.701, grad=0.000)
# step 236 loss: Value(data=14.553, grad=0.000)
# step 237 loss: Value(data=4.819, grad=0.000)
# step 238 loss: Value(data=7.773, grad=0.000)
# step 239 loss: Value(data=10.869, grad=0.000)
# step 240 loss: Value(data=11.803, grad=0.000)
# step 241 loss: Value(data=17.178, grad=0.000)
# step 242 loss: Value(data=7.880, grad=0.000)
# step 243 loss: Value(data=8.238, grad=0.000)
# step 244 loss: Value(data=9.234, grad=0.000)
# step 245 loss: Value(data=18.348, grad=0.000)
# step 246 loss: Value(data=11.542, grad=0.000)
# step 247 loss: Value(data=16.953, grad=0.000)
# step 248 loss: Value(data=5.060, grad=0.000)
# step 249 loss: Value(data=10.459, grad=0.000)
# step 250 loss: Value(data=12.486, grad=0.000)
# step 251 loss: Value(data=8.298, grad=0.000)
# step 252 loss: Value(data=10.449, grad=0.000)
# step 253 loss: Value(data=9.639, grad=0.000)
# step 254 loss: Value(data=9.472, grad=0.000)
# step 255 loss: Value(data=4.926, grad=0.000)
# step 256 loss: Value(data=14.384, grad=0.000)
# step 257 loss: Value(data=14.932, grad=0.000)
# step 258 loss: Value(data=7.396, grad=0.000)
# step 259 loss: Value(data=12.113, grad=0.000)
# step 260 loss: Value(data=9.101, grad=0.000)
# step 261 loss: Value(data=5.098, grad=0.000)
# step 262 loss: Value(data=13.718, grad=0.000)
# step 263 loss: Value(data=6.894, grad=0.000)
# step 264 loss: Value(data=21.788, grad=0.000)
# step 265 loss: Value(data=6.638, grad=0.000)
# step 266 loss: Value(data=8.951, grad=0.000)
# step 267 loss: Value(data=14.682, grad=0.000)
# step 268 loss: Value(data=19.373, grad=0.000)
# step 269 loss: Value(data=14.796, grad=0.000)
# step 270 loss: Value(data=16.314, grad=0.000)
# step 271 loss: Value(data=11.062, grad=0.000)
# step 272 loss: Value(data=9.817, grad=0.000)
# step 273 loss: Value(data=8.243, grad=0.000)
# step 274 loss: Value(data=11.647, grad=0.000)
# step 275 loss: Value(data=12.051, grad=0.000)
# step 276 loss: Value(data=15.040, grad=0.000)
# step 277 loss: Value(data=11.357, grad=0.000)
# step 278 loss: Value(data=16.618, grad=0.000)
# step 279 loss: Value(data=10.104, grad=0.000)
# step 280 loss: Value(data=10.162, grad=0.000)
# step 281 loss: Value(data=9.046, grad=0.000)
# step 282 loss: Value(data=6.679, grad=0.000)
# step 283 loss: Value(data=6.859, grad=0.000)
# step 284 loss: Value(data=9.712, grad=0.000)
# step 285 loss: Value(data=12.706, grad=0.000)
# step 286 loss: Value(data=12.991, grad=0.000)
# step 287 loss: Value(data=12.083, grad=0.000)
# step 288 loss: Value(data=6.746, grad=0.000)
# step 289 loss: Value(data=16.374, grad=0.000)
# step 290 loss: Value(data=7.203, grad=0.000)
# step 291 loss: Value(data=6.636, grad=0.000)
# step 292 loss: Value(data=7.545, grad=0.000)
# step 293 loss: Value(data=6.544, grad=0.000)
# step 294 loss: Value(data=9.069, grad=0.000)
# step 295 loss: Value(data=7.687, grad=0.000)
# step 296 loss: Value(data=8.578, grad=0.000)
# step 297 loss: Value(data=4.891, grad=0.000)
# step 298 loss: Value(data=7.647, grad=0.000)
# step 299 loss: Value(data=11.578, grad=0.000)
# step 300 loss: Value(data=9.446, grad=0.000)
# step 301 loss: Value(data=6.466, grad=0.000)
# step 302 loss: Value(data=4.301, grad=0.000)
# step 303 loss: Value(data=7.842, grad=0.000)
# step 304 loss: Value(data=12.019, grad=0.000)
# step 305 loss: Value(data=6.403, grad=0.000)
# step 306 loss: Value(data=10.578, grad=0.000)
# step 307 loss: Value(data=7.866, grad=0.000)
# step 308 loss: Value(data=8.475, grad=0.000)
# step 309 loss: Value(data=13.945, grad=0.000)
# step 310 loss: Value(data=7.933, grad=0.000)
# step 311 loss: Value(data=8.220, grad=0.000)
# step 312 loss: Value(data=7.720, grad=0.000)
# step 313 loss: Value(data=7.480, grad=0.000)
# step 314 loss: Value(data=9.467, grad=0.000)
# step 315 loss: Value(data=6.940, grad=0.000)
# step 316 loss: Value(data=6.940, grad=0.000)
# step 317 loss: Value(data=8.028, grad=0.000)
# step 318 loss: Value(data=3.460, grad=0.000)
# step 319 loss: Value(data=12.067, grad=0.000)
# step 320 loss: Value(data=7.142, grad=0.000)
# step 321 loss: Value(data=8.725, grad=0.000)
# step 322 loss: Value(data=10.881, grad=0.000)
# step 323 loss: Value(data=4.079, grad=0.000)
# step 324 loss: Value(data=8.099, grad=0.000)
# step 325 loss: Value(data=12.668, grad=0.000)
# step 326 loss: Value(data=7.868, grad=0.000)
# step 327 loss: Value(data=3.484, grad=0.000)
# step 328 loss: Value(data=7.580, grad=0.000)
# step 329 loss: Value(data=10.374, grad=0.000)
# step 330 loss: Value(data=4.454, grad=0.000)
# step 331 loss: Value(data=17.491, grad=0.000)
# step 332 loss: Value(data=11.718, grad=0.000)
# step 333 loss: Value(data=7.660, grad=0.000)
# step 334 loss: Value(data=13.412, grad=0.000)
# step 335 loss: Value(data=11.087, grad=0.000)
# step 336 loss: Value(data=4.248, grad=0.000)
# step 337 loss: Value(data=7.363, grad=0.000)
# step 338 loss: Value(data=9.234, grad=0.000)
# step 339 loss: Value(data=9.816, grad=0.000)
# step 340 loss: Value(data=7.594, grad=0.000)
# step 341 loss: Value(data=3.684, grad=0.000)
# step 342 loss: Value(data=6.524, grad=0.000)
# step 343 loss: Value(data=11.965, grad=0.000)
# step 344 loss: Value(data=6.351, grad=0.000)
# step 345 loss: Value(data=13.731, grad=0.000)
# step 346 loss: Value(data=7.372, grad=0.000)
# step 347 loss: Value(data=3.949, grad=0.000)
# step 348 loss: Value(data=8.932, grad=0.000)
# step 349 loss: Value(data=7.214, grad=0.000)
# step 350 loss: Value(data=5.951, grad=0.000)
# step 351 loss: Value(data=7.875, grad=0.000)
# step 352 loss: Value(data=7.709, grad=0.000)
# step 353 loss: Value(data=3.680, grad=0.000)
# step 354 loss: Value(data=6.162, grad=0.000)
# step 355 loss: Value(data=8.619, grad=0.000)
# step 356 loss: Value(data=5.493, grad=0.000)
# step 357 loss: Value(data=5.441, grad=0.000)
# step 358 loss: Value(data=5.679, grad=0.000)
# step 359 loss: Value(data=12.096, grad=0.000)
# step 360 loss: Value(data=7.207, grad=0.000)
# step 361 loss: Value(data=10.208, grad=0.000)
# step 362 loss: Value(data=8.736, grad=0.000)
# step 363 loss: Value(data=6.056, grad=0.000)
# step 364 loss: Value(data=5.692, grad=0.000)
# step 365 loss: Value(data=4.881, grad=0.000)
# step 366 loss: Value(data=6.422, grad=0.000)
# step 367 loss: Value(data=2.949, grad=0.000)
# step 368 loss: Value(data=4.246, grad=0.000)
# step 369 loss: Value(data=6.077, grad=0.000)
# step 370 loss: Value(data=8.856, grad=0.000)
# step 371 loss: Value(data=6.699, grad=0.000)
# step 372 loss: Value(data=3.497, grad=0.000)
# step 373 loss: Value(data=5.818, grad=0.000)
# step 374 loss: Value(data=5.656, grad=0.000)
# step 375 loss: Value(data=8.237, grad=0.000)
# step 376 loss: Value(data=11.414, grad=0.000)
# step 377 loss: Value(data=3.700, grad=0.000)
# step 378 loss: Value(data=6.637, grad=0.000)
# step 379 loss: Value(data=8.009, grad=0.000)
# step 380 loss: Value(data=3.169, grad=0.000)
# step 381 loss: Value(data=9.232, grad=0.000)
# step 382 loss: Value(data=3.747, grad=0.000)
# step 383 loss: Value(data=6.428, grad=0.000)
# step 384 loss: Value(data=8.882, grad=0.000)
# step 385 loss: Value(data=3.571, grad=0.000)
# step 386 loss: Value(data=5.323, grad=0.000)
# step 387 loss: Value(data=13.024, grad=0.000)
# step 388 loss: Value(data=5.570, grad=0.000)
# step 389 loss: Value(data=6.096, grad=0.000)
# step 390 loss: Value(data=4.919, grad=0.000)
# step 391 loss: Value(data=9.751, grad=0.000)
# step 392 loss: Value(data=10.535, grad=0.000)
# step 393 loss: Value(data=3.199, grad=0.000)
# step 394 loss: Value(data=6.595, grad=0.000)
# step 395 loss: Value(data=4.994, grad=0.000)
# step 396 loss: Value(data=3.823, grad=0.000)
# step 397 loss: Value(data=4.665, grad=0.000)
# step 398 loss: Value(data=3.634, grad=0.000)
# step 399 loss: Value(data=4.720, grad=0.000)
# step 400 loss: Value(data=6.009, grad=0.000)
# step 401 loss: Value(data=6.015, grad=0.000)
# step 402 loss: Value(data=4.247, grad=0.000)
# step 403 loss: Value(data=3.184, grad=0.000)
# step 404 loss: Value(data=5.159, grad=0.000)
# step 405 loss: Value(data=3.884, grad=0.000)
# step 406 loss: Value(data=5.915, grad=0.000)
# step 407 loss: Value(data=5.545, grad=0.000)
# step 408 loss: Value(data=8.603, grad=0.000)
# step 409 loss: Value(data=8.796, grad=0.000)
# step 410 loss: Value(data=6.360, grad=0.000)
# step 411 loss: Value(data=5.627, grad=0.000)
# step 412 loss: Value(data=1.699, grad=0.000)
# step 413 loss: Value(data=6.093, grad=0.000)
# step 414 loss: Value(data=4.290, grad=0.000)
# step 415 loss: Value(data=9.809, grad=0.000)
# step 416 loss: Value(data=2.147, grad=0.000)
# step 417 loss: Value(data=4.225, grad=0.000)
# step 418 loss: Value(data=2.883, grad=0.000)
# step 419 loss: Value(data=4.872, grad=0.000)
# step 420 loss: Value(data=7.285, grad=0.000)
# step 421 loss: Value(data=8.533, grad=0.000)
# step 422 loss: Value(data=4.625, grad=0.000)
# step 423 loss: Value(data=5.512, grad=0.000)
# step 424 loss: Value(data=3.273, grad=0.000)
# step 425 loss: Value(data=7.529, grad=0.000)
# step 426 loss: Value(data=4.273, grad=0.000)
# step 427 loss: Value(data=4.155, grad=0.000)
# step 428 loss: Value(data=5.495, grad=0.000)
# step 429 loss: Value(data=5.866, grad=0.000)
# step 430 loss: Value(data=3.185, grad=0.000)
# step 431 loss: Value(data=6.726, grad=0.000)
# step 432 loss: Value(data=6.091, grad=0.000)
# step 433 loss: Value(data=2.807, grad=0.000)
# step 434 loss: Value(data=12.137, grad=0.000)
# step 435 loss: Value(data=4.015, grad=0.000)
# step 436 loss: Value(data=7.300, grad=0.000)
# step 437 loss: Value(data=3.160, grad=0.000)
# step 438 loss: Value(data=7.404, grad=0.000)
# step 439 loss: Value(data=7.772, grad=0.000)
# step 440 loss: Value(data=5.484, grad=0.000)
# step 441 loss: Value(data=4.516, grad=0.000)
# step 442 loss: Value(data=3.943, grad=0.000)
# step 443 loss: Value(data=4.602, grad=0.000)
# step 444 loss: Value(data=6.890, grad=0.000)
# step 445 loss: Value(data=5.529, grad=0.000)
# step 446 loss: Value(data=2.829, grad=0.000)
# step 447 loss: Value(data=7.720, grad=0.000)
# step 448 loss: Value(data=5.914, grad=0.000)
# step 449 loss: Value(data=4.037, grad=0.000)
# step 450 loss: Value(data=2.543, grad=0.000)
# step 451 loss: Value(data=5.135, grad=0.000)
# step 452 loss: Value(data=3.702, grad=0.000)
# step 453 loss: Value(data=5.038, grad=0.000)
# step 454 loss: Value(data=3.908, grad=0.000)
# step 455 loss: Value(data=4.817, grad=0.000)
# step 456 loss: Value(data=3.909, grad=0.000)
# step 457 loss: Value(data=7.054, grad=0.000)
# step 458 loss: Value(data=4.347, grad=0.000)
# step 459 loss: Value(data=4.077, grad=0.000)
# step 460 loss: Value(data=6.542, grad=0.000)
# step 461 loss: Value(data=5.532, grad=0.000)
# step 462 loss: Value(data=5.309, grad=0.000)
# step 463 loss: Value(data=6.941, grad=0.000)
# step 464 loss: Value(data=2.397, grad=0.000)
# step 465 loss: Value(data=9.881, grad=0.000)
# step 466 loss: Value(data=7.378, grad=0.000)
# step 467 loss: Value(data=7.591, grad=0.000)
# step 468 loss: Value(data=7.209, grad=0.000)
# step 469 loss: Value(data=4.410, grad=0.000)
# step 470 loss: Value(data=3.308, grad=0.000)
# step 471 loss: Value(data=2.618, grad=0.000)
# step 472 loss: Value(data=3.459, grad=0.000)
# step 473 loss: Value(data=7.965, grad=0.000)
# step 474 loss: Value(data=1.993, grad=0.000)
# step 475 loss: Value(data=4.881, grad=0.000)
# step 476 loss: Value(data=6.057, grad=0.000)
# step 477 loss: Value(data=5.691, grad=0.000)
# step 478 loss: Value(data=5.169, grad=0.000)
# step 479 loss: Value(data=6.373, grad=0.000)
# step 480 loss: Value(data=5.172, grad=0.000)
# step 481 loss: Value(data=5.517, grad=0.000)
# step 482 loss: Value(data=2.809, grad=0.000)
# step 483 loss: Value(data=2.414, grad=0.000)
# step 484 loss: Value(data=3.829, grad=0.000)
# step 485 loss: Value(data=5.345, grad=0.000)
# step 486 loss: Value(data=3.611, grad=0.000)
# step 487 loss: Value(data=5.571, grad=0.000)
# step 488 loss: Value(data=1.617, grad=0.000)
# step 489 loss: Value(data=9.431, grad=0.000)
# step 490 loss: Value(data=3.121, grad=0.000)
# step 491 loss: Value(data=4.602, grad=0.000)
# step 492 loss: Value(data=3.888, grad=0.000)
# step 493 loss: Value(data=10.045, grad=0.000)
# step 494 loss: Value(data=2.616, grad=0.000)
# step 495 loss: Value(data=2.774, grad=0.000)

# %%
# final loss on test set
x_test = x[-batch_size:]
y_test = y[-batch_size:]

# running the model over the dataset
ypred = []
for j in range(batch_size):
    ypred.append(model(x_test[j]))

# MSE loss function
loss_batch = [(yhat - ytrue)**2 for ytrue, yhat in zip(y_test, ypred)]
loss = 0.0
for k in loss_batch: # sum() doesn't work for some reason so we've gotta do it manually
    loss = loss + k
print(f'final test loss: {loss}')
# Out:
# final test loss: Value(data=2.415, grad=0.000)

# %%
model.parameters()
# Out:
# [Value(data=0.591, grad=0.000),
#  Value(data=0.686, grad=0.000),
#  Value(data=0.750, grad=0.000),
#  Value(data=0.171, grad=0.000),
#  Value(data=0.000, grad=0.000),
#  Value(data=-0.970, grad=0.000),
#  Value(data=0.788, grad=-0.015),
#  Value(data=-0.152, grad=1.462),
#  Value(data=0.447, grad=0.997),
#  Value(data=0.032, grad=-0.629),
#  Value(data=-0.732, grad=0.000),
#  Value(data=-0.745, grad=0.187),
#  Value(data=-0.423, grad=-0.193),
#  Value(data=0.248, grad=0.654),
#  Value(data=0.054, grad=-0.757),
#  Value(data=-0.978, grad=0.000),
#  Value(data=0.389, grad=-0.468),
#  Value(data=-0.881, grad=1.622),
#  Value(data=-0.689, grad=0.716),
#  Value(data=0.040, grad=-1.345),
#  Value(data=-0.823, grad=0.000),
#  Value(data=0.966, grad=-0.254),
#  Value(data=-0.265, grad=0.944),
#  Value(data=0.596, grad=0.754),
#  Value(data=0.025, grad=-1.029),
#  Value(data=0.297, grad=0.000),
#  Value(data=0.707, grad=0.670),
#  Value(data=0.839, grad=-3.749),
#  Value(data=-0.472, grad=-1.008),
#  Value(data=0.228, grad=-0.403),
#  Value(data=0.924, grad=0.000),
#  Value(data=-0.385, grad=0.229),
#  Value(data=0.671, grad=-2.854),
#  Value(data=0.516, grad=-0.596),
#  Value(data=0.408, grad=-3.417),
#  Value(data=0.718, grad=0.000),
#  Value(data=-0.847, grad=-0.456),
#  Value(data=-0.155, grad=-0.093),
#  Value(data=-0.242, grad=0.248),
#  Value(data=-0.253, grad=0.496),
#  Value(data=-0.075, grad=0.000),
#  Value(data=-0.086, grad=0.541),
#  Value(data=0.280, grad=0.539),
#  Value(data=0.636, grad=1.245),
#  Value(data=-0.134, grad=2.643),
#  Value(data=0.882, grad=0.000),
#  Value(data=0.565, grad=-0.017),
#  Value(data=-0.142, grad=0.046),
#  Value(data=0.559, grad=0.027),
#  Value(data=-0.028, grad=0.000),
#  Value(data=0.507, grad=0.000),
#  Value(data=-0.631, grad=-1.811),
#  Value(data=-0.657, grad=1.074),
#  Value(data=0.122, grad=0.485),
#  Value(data=-0.129, grad=0.395),
#  Value(data=0.383, grad=0.000),
#  Value(data=0.185, grad=-0.205),
#  Value(data=0.546, grad=1.443),
#  Value(data=0.142, grad=0.462),
#  Value(data=-0.481, grad=1.811),
#  Value(data=0.901, grad=0.000),
#  Value(data=0.425, grad=0.346),
#  Value(data=0.484, grad=0.908),
#  Value(data=0.852, grad=0.527),
#  Value(data=-0.246, grad=0.936),
#  Value(data=0.335, grad=0.000),
#  Value(data=-0.190, grad=-2.023),
#  Value(data=-0.371, grad=1.623),
#  Value(data=-0.062, grad=1.176),
#  Value(data=-0.174, grad=-1.896),
#  Value(data=-0.287, grad=0.000),
#  Value(data=0.490, grad=-0.547),
#  Value(data=-0.438, grad=2.012),
#  Value(data=-0.282, grad=0.929),
#  Value(data=0.026, grad=-1.617),
#  Value(data=0.150, grad=0.000),
#  Value(data=-0.301, grad=-0.735),
#  Value(data=-0.715, grad=1.030),
#  Value(data=0.861, grad=1.373),
#  Value(data=0.078, grad=-0.696),
#  Value(data=-0.694, grad=0.000),
#  Value(data=0.698, grad=0.669),
#  Value(data=0.079, grad=0.225),
#  Value(data=0.797, grad=0.850),
#  Value(data=-0.030, grad=0.837),
#  Value(data=0.419, grad=0.000),
#  Value(data=0.406, grad=0.388),
#  Value(data=-0.527, grad=-2.149),
#  Value(data=-0.732, grad=-0.609),
#  Value(data=0.082, grad=0.944),
#  Value(data=-0.525, grad=0.000),
#  Value(data=-0.723, grad=0.001),
#  Value(data=-0.036, grad=0.469),
#  Value(data=0.415, grad=1.585),
#  Value(data=-0.073, grad=0.744),
#  Value(data=-0.044, grad=0.000),
#  Value(data=0.155, grad=0.462),
#  Value(data=0.354, grad=0.794),
#  Value(data=0.094, grad=0.238),
#  Value(data=-0.292, grad=1.000),
#  Value(data=-0.862, grad=0.000),
#  Value(data=-0.576, grad=0.056),
#  Value(data=0.554, grad=-0.834),
#  Value(data=0.092, grad=-0.500),
#  Value(data=0.104, grad=-0.814),
#  Value(data=0.207, grad=0.000),
#  Value(data=-0.507, grad=-0.689),
#  Value(data=-0.702, grad=0.745),
#  Value(data=-0.449, grad=0.597),
#  Value(data=-0.031, grad=-1.134),
#  Value(data=-0.410, grad=0.000),
#  Value(data=-0.495, grad=-0.398),
#  Value(data=0.861, grad=-1.385),
#  Value(data=0.660, grad=-0.657),
#  Value(data=0.248, grad=-3.356),
#  Value(data=0.958, grad=0.000),
#  Value(data=-1.008, grad=1.278),
#  Value(data=-0.090, grad=-2.473),
#  Value(data=-0.470, grad=-1.479),
#  Value(data=0.138, grad=1.179),
#  Value(data=0.676, grad=0.000),
#  Value(data=0.371, grad=0.052),
#  Value(data=0.311, grad=-0.129),
#  Value(data=-0.705, grad=-0.026),
#  Value(data=-0.114, grad=-0.006),
#  Value(data=0.612, grad=0.000),
#  Value(data=0.640, grad=-0.152),
#  Value(data=-0.183, grad=0.632),
#  Value(data=-0.643, grad=0.345),
#  Value(data=-0.115, grad=-0.209),
#  Value(data=-0.292, grad=0.000),
#  Value(data=0.098, grad=0.137),
#  Value(data=0.334, grad=0.463),
#  Value(data=-0.287, grad=-0.192),
#  Value(data=-0.232, grad=0.522),
#  Value(data=-0.702, grad=0.000),
#  Value(data=-0.471, grad=0.502),
#  Value(data=-0.031, grad=0.699),
#  Value(data=0.198, grad=0.405),
#  Value(data=0.013, grad=0.136),
#  Value(data=-0.168, grad=0.000),
#  Value(data=-0.572, grad=0.162),
#  Value(data=0.189, grad=-0.512),
#  Value(data=0.261, grad=-0.209),
#  Value(data=0.086, grad=-0.358),
#  Value(data=-0.585, grad=0.000),
#  Value(data=0.562, grad=-0.016),
#  Value(data=0.020, grad=-0.042),
#  Value(data=0.945, grad=-0.215),
#  Value(data=-0.010, grad=0.014),
#  Value(data=0.051, grad=0.000),
#  Value(data=0.723, grad=-0.761),
#  Value(data=-0.118, grad=1.553),
#  Value(data=-0.858, grad=0.261),
#  Value(data=-0.150, grad=-1.603),
#  Value(data=0.393, grad=0.000),
#  Value(data=0.471, grad=-0.239),
#  Value(data=-0.538, grad=0.798),
#  Value(data=0.978, grad=0.626),
#  Value(data=0.007, grad=0.056),
#  Value(data=0.057, grad=0.000),
#  Value(data=-0.513, grad=-0.770),
#  Value(data=-0.745, grad=0.222),
#  Value(data=-0.467, grad=3.472),
#  Value(data=-0.309, grad=-0.541),
#  Value(data=0.789, grad=-2.951),
#  Value(data=1.130, grad=-3.957),
#  Value(data=-0.479, grad=-1.033),
#  Value(data=-0.658, grad=-0.701),
#  Value(data=-0.011, grad=-0.687),
#  Value(data=-0.863, grad=-0.415),
#  Value(data=-0.763, grad=-0.767),
#  Value(data=-0.421, grad=-2.636),
#  Value(data=-0.870, grad=0.368),
#  Value(data=-0.581, grad=2.178),
#  Value(data=-0.928, grad=-0.721),
#  Value(data=-0.890, grad=-1.499),
#  Value(data=0.461, grad=3.634),
#  Value(data=-0.952, grad=-0.239),
#  Value(data=-0.562, grad=-0.098),
#  Value(data=0.618, grad=-0.643),
#  Value(data=-0.316, grad=1.432),
#  Value(data=0.749, grad=-2.539),
#  Value(data=0.667, grad=-1.830),
#  Value(data=0.026, grad=-0.451),
#  Value(data=-0.202, grad=1.853),
#  Value(data=-0.448, grad=-0.420),
#  Value(data=-0.902, grad=0.028),
#  Value(data=0.393, grad=-0.576),
#  Value(data=0.251, grad=-1.557),
#  Value(data=-0.402, grad=1.824),
#  Value(data=-0.248, grad=-0.223),
#  Value(data=0.428, grad=-0.026)]
